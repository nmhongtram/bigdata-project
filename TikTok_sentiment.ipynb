# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Cài đặt và tải các thư viện**

# %%
# !pip install pyspark pyvi underthesea emoji unidecode transformers
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting underthesea
#   Downloading underthesea-6.8.4-py3-none-any.whl.metadata (15 kB)
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pyvi) (1.6.1)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.11/dist-packages (from underthesea) (8.1.8)
# Collecting python-crfsuite>=0.9.6 (from underthesea)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from underthesea) (3.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from underthesea) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from underthesea) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from underthesea) (1.4.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from underthesea) (6.0.2)
# Collecting underthesea-core==1.0.4 (from underthesea)
#   Downloading underthesea_core-1.0.4-cp311-cp311-manylinux2010_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (2025.4.26)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 23.8 MB/s eta 0:00:00
# Downloading underthesea-6.8.4-py3-none-any.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 39.6 MB/s eta 0:00:00
# Downloading underthesea_core-1.0.4-cp311-cp311-manylinux2010_x86_64.whl (657 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 19.9 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 22.6 MB/s eta 0:00:00
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 12.0 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.4 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: underthesea-core, unidecode, python-crfsuite, emoji, underthesea, sklearn-crfsuite, pyvi
# Successfully installed emoji-2.14.1 python-crfsuite-0.9.11 pyvi-0.1.1 sklearn-crfsuite-0.5.0 underthesea-6.8.4 underthesea-core-1.0.4 unidecode-1.4.0

# %%
# tải font cho wordcloud
# !wget -O montserrat.ttf "https://github.com/JulietaUla/Montserrat/raw/master/fonts/ttf/Montserrat-Black.ttf"
# Out:
# --2025-05-08 03:26:22--  https://github.com/JulietaUla/Montserrat/raw/master/fonts/ttf/Montserrat-Black.ttf
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/JulietaUla/Montserrat/master/fonts/ttf/Montserrat-Black.ttf [following]
# --2025-05-08 03:26:23--  https://raw.githubusercontent.com/JulietaUla/Montserrat/master/fonts/ttf/Montserrat-Black.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 462844 (452K) [application/octet-stream]
# Saving to: ‘montserrat.ttf’
#
# montserrat.ttf      100%[===================>] 452.00K  --.-KB/s    in 0.05s
#
# 2025-05-08 03:26:23 (9.33 MB/s) - ‘montserrat.ttf’ saved [462844/462844]

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import Counter

# PySpark SQL
from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql.types import ArrayType, NumericType, IntegerType, StringType, FloatType, DoubleType
from pyspark.sql.types import StructType, StructField
from pyspark.sql import functions as F
from pyspark.sql.functions import udf, col, from_json

# PySpark ML
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import CountVectorizer

# PhoBERT & Tensorflow
import torch
from transformers import AutoTokenizer, AutoModel
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping

# Scikit learn for Machine Learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV

# Natural Language Processing Libraries
from pyvi import ViTokenizer, ViPosTagger
from underthesea import ner
import re
import emoji
import unicodedata

from functools import reduce

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Save and Load model
import pickle


import warnings
warnings.filterwarnings('ignore')

# %%
plt.style.use('default')

# %% [markdown]
# ---
# # **1. Import data vào Spark Dataframe**
# ---

# %%
# Tạo SparkSession
spark = SparkSession.builder.appName("TikTokSentimentAnalysis").getOrCreate()

# %% [markdown]
# Dữ liệu về video

# %%
video_df = spark.read.option("header", True) \
    .option("multiLine", True) \
    .option("quote", '"') \
    .option("escape", '"') \
    .option("mode", "PERMISSIVE") \
    .option("delimiter", "\t") \
    .csv("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/all_videos.tsv", inferSchema=True)

video_df.show(20)
# Out:
# +--------------------+------------+------------+----------+-------------------+--------------------+---------+--------------+--------------------+-------------------+-----+-------+--------+-----------+--------------------+--------------------+--------------------+--------------------+---------+--------------------
false|  false|   false|      false|                NULL|['https://api.api...|                  []|{'musicName': 'nh...|   124700|kem chống nắng an...|       101|Kem chống nắng an...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '675458465...|          12|          24|1743312719|2025-03-30 05:31:59|                  []|      313|            []|[{'id': '16436164...|7487471073894616326|false|  false|   false|      false|                NULL|['https://api.api...|                  []|{'musicName': 'nh...|    18500|kem chống nắng an...|        17|Hôm nay cùng Thái...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '695024971...|          66|          63|1724046189|2024-08-19 05:43:09|[{'id': '71743192...|      505|            []|[{'id': '', 'name...|7404721959348620560|false|  false|   false|      false|                NULL|['https://api.api...|      ['@Lynh Lynh']|{'musicName': 'nh...|    43000|kem chống nắng an...|        11|Trả lời @Lynh Lyn...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '723686084...|          51|          10|1732122973|2024-11-20 17:16:13|[{'id': '67837610...|      190|            []|[{'id': '', 'name...|7439411489494093099|false|  false|   false|      false|                NULL|['https://api.api...|       ['@SHISEIDO']|{'musicName': 'so...|    57300|kem chống nắng an...|        67|@SHISEIDO Anessa ...|          en|{'height': 1024, ...|https://www.tikto...|
# |{'id': '739254142...|           1|           2|1721306838|2024-07-18 12:47:18|                  []|       14|            []|[{'id': '370921',...|7392956565617184007|false|  false|   false|      false|{'address': 'Viet...|['https://api.api...|                  []|{'musicName': 'nh...|     3764|kem chống nắng an...|         1|Kem chống nắng An...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '663656725...|         159|          60|1666093040|2022-10-18 11:37:20|                  []|     1202|            []|[{'id': '17006427...|7155814301457075482|false|  false|   false|      false|                NULL|['https://api.api...|                  []|{'musicName': "Ch...|   153300|kem chống nắng an...|       131|Kem chống nắng ch...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '730166696...|          13|          16|1702292595|2023-12-11 11:03:15|                  []|       74|            []|[{'id': '16044964...|7311291005154643205|false|  false|   false|      false|                NULL|['https://api.api...|                  []|{'musicName': 'So...|    10800|kem chống nắng an...|       150|Unbox kem chống n...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '681616612...|          15|         122|1706285544|2024-01-26 16:12:24|                  []|      514|            []|[{'id': '17022461...|7328440584836762888|false|  false|   false|      false|                NULL|['https://api.api...|                  []|{'musicName': 'Pa...|    44600|kem chống nắng an...|        17|KCN Anessa bị cay...|          vi|{'height': 1024, ...|https://www.tikto...|
# |{'id': '725925774...|          12|          20|1725162206|2024-09-01 03:43:26|                  []|      126|            []|[{'id': '72582147...|7409515224140713223|false|  false|   false|      false|                NULL|['https://api.api...|                  []|{'musicName': 'nh...|    11600|kem chống nắng an...|         3|Test độ bám kem c...|          vi|{'height': 1024, ...|https://www.tikto...|
# +--------------------+------------+------------+----------+-------------------+--------------------+---------+--------------+--------------------+-------------------+-----+-------+--------+-----------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+----------+--------------------+------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Dữ liệu về comment

# %%
comment_df = spark.read.option("header", True) \
    .option("multiLine", True) \
    .option("quote", '"') \
    .option("escape", '"') \
    .option("mode", "PERMISSIVE") \
    .option("delimiter", "\t") \
    .csv("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/all_comments_labeled.tsv", inferSchema=True)

comment_df.show(20)
# Out:
# +--------------------+--------------------+--------------------+-------------------+----------+-------------------+--------------------+-----+---------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# |         videoWebUrl|   submittedVideoUrl|               input|                cid|createTime|      createTimeISO|                text|label|diggCount|likedByAuthor|pinnedByAuthor|repliesToId|replyCommentTotal|                uid|        uniqueId|     avatarThumbnail|
# +--------------------+--------------------+--------------------+-------------------+----------+-------------------+--------------------+-----+---------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# |https://www.tikto...|https://www.tikto...|https://www.tikto...|6978487559790527233|1624805757|2021-06-27 14:55:57|Cảm ơn bác sĩ chị...|  pos|        1|         true|         false|       NULL|              2.0|6761019601562387457|    minhhien3823|https://p16-sign-...|
# |https://www.tikto...|https://www.tikto...|https://www.tikto...|
+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ---
# # **2. Kiểm tra sơ bộ dữ liệu**
# ---

# %%
print(f"Số lượng videos: {video_df.count()}")
print(f"Số lượng comments: {comment_df.count()}")
# Out:
# Số lượng videos: 309
# Số lượng comments: 12020

# %% [markdown]
# ## **2.1. Hiển thị schema của video_df và comment_df**

# %%
video_df.printSchema()
# Out:
# root
#  |-- authorMeta: string (nullable = true)
#  |-- collectCount: integer (nullable = true)
#  |-- commentCount: integer (nullable = true)
#  |-- createTime: integer (nullable = true)
#  |-- createTimeISO: timestamp (nullable = true)
#  |-- detailedMentions: string (nullable = true)
#  |-- diggCount: integer (nullable = true)
#  |-- effectStickers: string (nullable = true)
#  |-- hashtags: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- isAd: boolean (nullable = true)
#  |-- isMuted: boolean (nullable = true)
#  |-- isPinned: boolean (nullable = true)
#  |-- isSlideshow: boolean (nullable = true)
#  |-- locationMeta: string (nullable = true)
#  |-- mediaUrls: string (nullable = true)
#  |-- mentions: string (nullable = true)
#  |-- musicMeta: string (nullable = true)
#  |-- playCount: integer (nullable = true)
#  |-- searchQuery: string (nullable = true)
#  |-- shareCount: integer (nullable = true)
#  |-- text: string (nullable = true)
#  |-- textLanguage: string (nullable = true)
#  |-- videoMeta: string (nullable = true)
#  |-- webVideoUrl: string (nullable = true)

# %%
comment_df.printSchema()
# Out:
# root
#  |-- videoWebUrl: string (nullable = true)
#  |-- submittedVideoUrl: string (nullable = true)
#  |-- input: string (nullable = true)
#  |-- cid: string (nullable = true)
#  |-- createTime: integer (nullable = true)
#  |-- createTimeISO: timestamp (nullable = true)
#  |-- text: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- diggCount: integer (nullable = true)
#  |-- likedByAuthor: boolean (nullable = true)
#  |-- pinnedByAuthor: boolean (nullable = true)
#  |-- repliesToId: string (nullable = true)
#  |-- replyCommentTotal: double (nullable = true)
#  |-- uid: string (nullable = true)
#  |-- uniqueId: string (nullable = true)
#  |-- avatarThumbnail: string (nullable = true)

# %% [markdown]
# ## **2.2. Chuẩn hóa kiểu dữ liệu cho video_df**

# %% [markdown]
# Các cột bị nhận diện sai kiểu dữ liệu
#
# - authorMeta: dict
#
# - detailedMentions: list
#
# - effectStickers: list các dict
#
# - hashtags:  list các dict
#
# - locationMeta: dict
#
# - mediaUrl: list các str
#
# - mentions: list các str
#
# - musicMeta: dict
#
# - videoMeta: dict

# %% [markdown]
# ### 2.2.1. Trích xuất dữ liệu cho cột videoMeta, thêm cột duration

# %%
video_meta_schema = StructType([
    StructField("height", IntegerType(), True),
    StructField("width", IntegerType(), True),
    StructField("duration", IntegerType(), True),
    StructField("coverUrl", StringType(), True),
    StructField("originalCoverUrl", StringType(), True),
    StructField("definition", StringType(), True),
    StructField("format", StringType(), True),
    StructField("subtitleLinks", StringType(), True),
    StructField("downloadAddr", StringType(), True)
])

video_df = video_df.withColumn("video_meta", from_json("videoMeta", video_meta_schema))
video_df = video_df.withColumn("duration", col("video_meta.duration"))

# %% [markdown]
# ### 2.2.2. Trích xuất dữ liệu cho cột hashtags

# %%
# Khai báo schema của 1 hashtag (struct) trong array
hashtag_schema = ArrayType(StructType([
                          StructField("id", StringType(), True),
                          StructField("name", StringType(), True),
                          StructField("title", StringType(), True),
                          StructField("cover", StringType(), True)]))

video_df = video_df.withColumn("hashtags_json", from_json(col("hashtags"), hashtag_schema))

# %%
video_df.printSchema()
# Out:
# root
#  |-- authorMeta: string (nullable = true)
#  |-- collectCount: integer (nullable = true)
#  |-- commentCount: integer (nullable = true)
#  |-- createTime: integer (nullable = true)
#  |-- createTimeISO: timestamp (nullable = true)
#  |-- detailedMentions: string (nullable = true)
#  |-- diggCount: integer (nullable = true)
#  |-- effectStickers: string (nullable = true)
#  |-- hashtags: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- isAd: boolean (nullable = true)
#  |-- isMuted: boolean (nullable = true)
#  |-- isPinned: boolean (nullable = true)
#  |-- isSlideshow: boolean (nullable = true)
#  |-- locationMeta: string (nullable = true)
#  |-- mediaUrls: string (nullable = true)
#  |-- mentions: string (nullable = true)
#  |-- musicMeta: string (nullable = true)
#  |-- playCount: integer (nullable = true)
#  |-- searchQuery: string (nullable = true)
#  |-- shareCount: integer (nullable = true)
#  |-- text: string (nullable = true)
#  |-- textLanguage: string (nullable = true)
#  |-- videoMeta: string (nullable = true)
#  |-- webVideoUrl: string (nullable = true)
#  |-- video_meta: struct (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- duration: integer (nullable = true)
#  |    |-- coverUrl: string (nullable = true)
#  |    |-- originalCoverUrl: string (nullable = true)
#  |    |-- definition: string (nullable = true)
#  |    |-- format: string (nullable = true)
#  |    |-- subtitleLinks: string (nullable = true)
#  |    |-- downloadAddr: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- hashtags_json: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- cover: string (nullable = true)

# %% [markdown]
# ## **2.3. Thống kê mô tả các cột dữ liệu số**

# %% [markdown]
# Thống kê mô tả video_df

# %%
# Lọc các cột có kiểu dữ liệu số (IntegerType, LongType, DoubleType, etc.)
numeric_columns = [f.name for f in video_df.schema.fields if isinstance(f.dataType, NumericType)]
video_df.select(numeric_columns).describe().show()
# Out:
# +-------+------------------+-----------------+--------------------+------------------+--------------------+-----------------+------------------+-----------------+
# |summary|      collectCount|     commentCount|          createTime|         diggCount|                  id|        playCount|        shareCount|         duration|
# +-------+------------------+-----------------+--------------------+------------------+--------------------+-----------------+------------------+-----------------+
# |  count|               309|              309|                 309|               309|                 309|              309|               309|              309|
# |   mean|1922.1423948220065|316.9935275080906|1.7134821276601942E9|20356.168284789645|7.359342864691018...|789773.2556634304| 523.8737864077669| 76.0453074433657|
# | stddev| 6685.136330612759|823.3936032858139|3.0847442071910113E7| 73576.72227803692|1.324834495585293...|2327024.561340124|1770.4529760803919|56.55423111893463|
# |    min|                 0|                0|          1601475088|                 3| 6878283120559410434|              149|                 0|                6|
# |    max|             64300|             7048|          1746114677|            685600| 7499505279512415518|         20100000|             16800|              341|
# +-------+------------------+-----------------+--------------------+------------------+--------------------+-----------------+------------------+-----------------+

# %% [markdown]
# Thống kê mô tả comment_df

# %%
numeric_columns = [f.name for f in comment_df.schema.fields if isinstance(f.dataType, NumericType)]
comment_df.select(numeric_columns).describe().show()
# Out:
# +-------+--------------------+------------------+------------------+
# |summary|          createTime|         diggCount| replyCommentTotal|
# +-------+--------------------+------------------+------------------+
# |  count|               12020|             12020|             10317|
# |   mean|1.7142344449569051E9|20.109317803660566|1.9370941165067364|
# | stddev|3.0986266151981387E7|333.16854993453535| 9.807601318848045|
# |    min|          1601475584|                 0|               0.0|
# |    max|          1746129276|             24748|             551.0|
# +-------+--------------------+------------------+------------------+

# %% [markdown]
# ---
# # **3. EDA Metadata liên quan đến video**
# ---

# %% [markdown]
# ## **3.1. Tính tổng số lượt xem, lượt thích, chia sẻ, bình luận, và lưu trữ video**

# %%
# Tính tổng số lượt xem, lượt thích, chia sẻ, bình luận, và lưu trữ video
video_summary = video_df.select(
    F.sum(F.col("playCount")).alias("total_playCount"),
    F.sum(F.col("diggCount")).alias("total_diggCount"),
    F.sum(F.col("shareCount")).alias("total_shareCount"),
    F.sum(F.col("commentCount")).alias("total_commentCount"),
    F.sum(F.col("collectCount")).alias("total_collectCount")
)

video_summary.show()
# Out:
# +---------------+---------------+----------------+------------------+------------------+
# |total_playCount|total_diggCount|total_shareCount|total_commentCount|total_collectCount|
# +---------------+---------------+----------------+------------------+------------------+
# |      244039936|        6290056|          161877|             97951|            593942|
# +---------------+---------------+----------------+------------------+------------------+

# %% [markdown]
# ## **3.2. Hiển thị các video với mức độ tương tác cao nhất**

# %% [markdown]
# ### 3.2.1. Top 10 video có lượt xem cao nhất

# %%
print('Top 10 video có lượt xem cao nhất')
video_df.filter(col("playCount").isNotNull()).orderBy(col("playCount").desc()).select("id", "text", "playCount", "diggCount", "shareCount", "commentCount").show(10, truncate=False)
# Out:
# Top 10 video có lượt xem cao nhất
# +-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+---------+----------+------------+
# |id                 |text                                                                                                                                                                                                                                                                |playCount|diggCount|shareCount|commentCount|
# +-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+---------+----------+------------+
# |7254045019642875142|Trả lời @Nguyễn Thị Nhung   Theo yêu cầu của mọi người. Mình sẽ test khả năng kháng nước của em kem chống nắng L'Oreal vạch đỏ qua UVCAM nha 😝 #goclamdep #reviewlamdep #kcn #kemchongnang #beautytok #review #lorealparis #uvfluid #learnontiktok #withbimm #dcgr |20100000 |25800    |826       |575         |
# |7251201629851127046|Chân ái hè này của em❤️ #halinh #halinhofficial #reviewlamdep #kemchongnang #suncream #suncreen #vichy #duongtrang #kemchongnangnangtone #fyp #xuhuong #xh #trending                                                                                                |15600000 |520800   |14800     |7048        |
# |7262615570766482695|Chân ai mới cho da dầu nha #LearnOnTikTok #bbskincare #beautytok #goclamdep #uvcameratest #beplain                                                                                                                                                                  |13500000 |128300   |2958      |2659        |
# |7319841581488475394|Có ai đoán được em kem chống nắng cuối khum? #kemchongnang #skincare #htxbeauty #lancertalents #otanetwork                                                                                                                                                          |11500000 |322800   |1826      |3476        |
# |7114272015275674907|Cách bôi kem chống nắng dễ vón siêu đẹp! Đơn giản và hiệu quả. Quan trọng nhất là thao tác! #SuThatLa #halinhofficial #ReviewLamDep #kemchongnang #larocheposay #sunscreen #kiemdau #skincare #makeup #trimun #xuhuong #lamdep #beauty                              |11400000 |653100   |12300     |5944        |
# |7374036464331476225|Hôm nay air hơi muộn một chút ạ                      🫶                                                                                #beplain #sunmuse #kcn                                                                         |3000000  |162000   |1664      |1037        |
# |7416714843895516424|Đánh kem chống nắng như chị đi, đẹp lém #fyp #dalba #dalbavn #dalbavietnam                                                                                                                                                            |2600000  |153700   |5035      |945         |
# |7247108428626447621|Goodbye my love 🥲 #halinh #halinhofficial #kemchongnang #larocheposay #reviewlamdep #xuhuong #xh #trend #viral #fyp #skincare #duongda #lamdep                                                                                       |4600000  |147800   |4065      |2940        |
# +-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+---------+----------+------------+
# only showing top 10 rows

# %% [markdown]
# ## **3.3. Phân tích hành vi tương tác với video quảng bá sản phẩm**

# %% [markdown]
# Mục tiêu: Tìm hiểu sự khác biệt về tương tác giữa video quảng cáo (isAd = True) và video thường.

# %%
video_df.groupBy("isAd").agg(
    F.count("*").alias("video_count"),
    F.avg("diggCount").alias("avg_likes"),
    F.avg("shareCount").alias("avg_shares"),
    F.avg("commentCount").alias("avg_comments"),
    F.avg("playCount").alias("avg_views")
).show()
# Out:
# +-----+-----------+------------------+-----------------+-----------------+------------------+
# | isAd|video_count|         avg_likes|       avg_shares|     avg_comments|         avg_views|
# +-----+-----------+------------------+-----------------+-----------------+------------------+
# | true|         42|37438.142857142855| 862.952380952381|516.1666666666666| 2734702.380952381|
# |false|        267|17669.116104868914|470.5355805243446|285.6629213483146|483829.34831460676|
# +-----+-----------+------------------+-----------------+-----------------+------------------+

# %% [markdown]
# - playCount cho biết video tiếp cận đến bao nhiêu người, còn diggCount cho biết bao nhiêu người thực sự thích video đó.
# - Tỷ lệ (diggCount + commentCount +shareCount) / playCount có thể dùng để đo mức độ tương tác (engagement rate) hoặc mức độ gây ấn tượng của nội dung.

# %%
# Tính engagement_rate và lấy giá trị trung bình theo isAd
engagement_df = video_df.withColumn("engagement_rate",(col("diggCount") + col("shareCount") + col("commentCount")) / col("playCount"))\
                                    .groupBy("isAd").agg(F.avg("engagement_rate").alias("avg_engagement_rate"))

# Chuyển sang Pandas để vẽ biểu đồ
engagement_pd = engagement_df.toPandas().sort_values("isAd")

labels = ['Non-Ads', 'Ads']
engagement_rates = engagement_pd['avg_engagement_rate'].tolist()

# %%
# Vẽ biểu đồ
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, engagement_rates, color=['skyblue', 'orange'])

# Ghi giá trị lên từng cột
for bar in bars:
    height = bar.get_height()
    plt.annotate(f'{height:.4f}',
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3),
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10)

plt.title('Engagement Rate trung bình\nVideo Ads vs Non-Ads', fontsize=14)
plt.ylim(0, max(engagement_rates) * 1.2)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
# Chuyển về pandas để vẽ boxplot phân bố engagement_rate
videos_pd = video_df.withColumn("engagement_rate",(col("diggCount") + col("shareCount") + col("commentCount")) / col("playCount")) \
                     .select("isAd", "engagement_rate") \
                     .dropna().toPandas()

plt.figure(figsize=(6,5))
sns.boxplot(data=videos_pd, x='isAd', y='engagement_rate', palette=['skyblue', 'orange'])
plt.xticks([0,1], ['Non-Ads', 'Ads'])
plt.xlabel(None)
plt.title("Phân bố Engagement Rate theo loại video")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-f2cba713cf9f>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=videos_pd, x='isAd', y='engagement_rate', palette=['skyblue', 'orange'])

# %% [markdown]
# ## **3.4. Thống kê hashtags**

# %%
# explode từng hashtag
hashtags_df = video_df.withColumn("hashtag", F.explode(col("hashtags_json"))).select(col("hashtag.name").alias("hashtag_name"))

# Lọc bỏ dòng trống trước khi đếm
hashtags_df_cleaned = hashtags_df.filter((col("hashtag_name").isNotNull()) & (col("hashtag_name") != "")).withColumn("hashtag_name", F.lower(F.trim(col("hashtag_name"))))

# Đếm số lần xuất hiện
hashtags_df_cleaned.groupBy("hashtag_name").count().orderBy("count", ascending=False).show(10, truncate=False)
# Out:
# +------------+-----+
# |hashtag_name|count|
# +------------+-----+
# |kemchongnang|116  |
# |reviewlamdep|82   |
# |goclamdep   |80   |
# |skincare    |62   |
# |beplain     |53   |
# |beautytok   |47   |
# |larocheposay|46   |
# |kcn         |45   |
# |xuhuong     |43   |
# |fyp         |36   |
# +------------+-----+
# only showing top 10 rows

# %%
# Lấy top 10 hashtag và chuyển thành pandas DataFrame
top10_hashtags = hashtags_df_cleaned.groupBy("hashtag_name") \
    .count() \
    .orderBy("count", ascending=False) \
    .limit(10) \
    .toPandas()

# Vẽ biểu đồ
plt.figure(figsize=(12,6))
plt.barh(top10_hashtags['hashtag_name'], top10_hashtags['count'], color='skyblue')
plt.xlabel("Tần suất xuất hiện")
# plt.ylabel("Hashtag")
plt.title("Top 10 Hashtag phổ biến")
plt.gca().invert_yaxis()  # Đảo ngược trục Y để hashtag có số lượng cao nhất ở trên cùng
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # **4. Tiền xử lý văn bản**
# ---

# %% [markdown]
# ## **4.1. Danh sách từ cần tra cứu**

# %% [markdown]
# Vì tách từ bằng PyVi sẽ có dấu gạch nối giữa các âm tiết.
#
# Cần chuyển danh sách stopword, teencode thành dạng có dấu gạch chân nối giữa các âm tiết

# %%
teencode_dict = {}
with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/teencode4.txt", "r", encoding="utf-8") as f:
    for line in f:
        if "\t" in line:
            key, value = line.strip().split("\t")
            key = key.replace(" ", "_")
            value = value.replace(" ", "_")
            teencode_dict[key] = value

stopword_list = []
with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/vietnamese-stopwords.txt", "r", encoding="utf-8") as f:
    for line in f:
        stopword = line.strip().replace(" ", "_")
        if stopword:
            stopword_list.append(stopword)

print("Teencode dictionary:")
print(teencode_dict)

print("\nStopword list:")
print(stopword_list)
# Out:
# Teencode dictionary:
# {'ctrai': 'con_trai', 'khôg': 'không', 'bme': 'bố_mẹ', 'cta': 'chúng_ta', 'mih': 'mình', 'cmnl': 'con_mẹ_nó_luôn', 'mqh': 'mối_quan_hệ', 'ùi': 'rồi', 'sem': 'xem', 'pải': 'phải', 'đel': 'đéo', 'cgai': 'con_gái', 'nhữg': 'những', 'mng': 'mọi_người', 'r': 'rồi', 'qtam': 'quan_tâm', 'thươg': '
nh', 'chí_chết', 'chính', 'chính_bản', 'chính_giữa', 'chính_là', 'chính_thị', 'chính_điểm', 'chùn_chùn', 'chùn_chũn', 'chú', 'chú_dẫn', 'chú_khách', 'chú_mày', 'chú_mình', 'chúng', 'chúng_mình', 'chúng_ta', 'chúng_tôi', 'chúng_ông', 'chăn_chắn', 'chăng', 'chăng_chắc', 'chăng_nữa', 'chơi', 'chơi_họ', 'chưa', 'chưa_bao_giờ', 'chưa_chắc', 'chưa_có', 'chưa_cần', 'chưa_dùng', 'chưa_dễ', 'chưa_kể', 'chưa_tính', 'chưa_từng', 'chầm_chập', 'chậc', 'chắc', 'chắc_chắn', 'chắc_dạ', 'chắc_hẳn', 'chắc_lòng', 'chắc_người', 'chắc_vào', 'chắc_ăn', 'chẳng_lẽ', 'chẳng_những', 'chẳng_nữa', 'chẳng_phải', 'chết_nỗi', 'chết_thật', 'chết_tiệt', 'chỉ', 'chỉ_chính', 'chỉ_có', 'chỉ_là', 'chỉ_tên', 'chỉn', 'chị', 'chị_bộ', 'chị_ấy', 'chịu', 'chịu_chưa', 'chịu_lời', 'chịu_tốt', 'chịu_ăn', 'chọn', 'chọn_bên', 'chọn_ra', 'chốc_chốc', 'chớ', 'chớ_chi', 'chớ_gì', 'chớ_không', 'chớ_kể', 'chớ_như', 'chợt', 'chợt_nghe', 'chợt_nhìn', 'chủn', 'chứ', 'chứ_ai', 'chứ_còn', 'chứ_gì', 'chứ_không', 'chứ_không_phải', 'chứ_lại', 'chứ_lị', 'chứ_như', 'chứ_sao', 'coi_bộ', 'coi_mòi', 'con', 'con_con', 'con_dạ', 'con_nhà', 'con_tính', 'cu_cậu', 'cuối', 'cuối_cùng', 'cuối_điểm', 'cuốn', 'cuộc', 'càng', 'càng_càng', 'càng_hay', 'cá_nhân', 'các', 'các_cậu', 'cách', 'cách_bức', 'cách_không', 'cách_nhau', 'cách_đều', 'cái', 'cái_gì', 'cái_họ', 'cái_đã', 'cái_đó', 'cái_ấy', 'câu_hỏi', 'cây', 'cây_nước', 'còn', 'còn_như', 'còn_nữa', 'còn_thời_gian', 'còn_về', 'có', 'có_ai', 'có_chuyện', 'có_chăng', 'có_chăng_là', 'có_chứ', 'có_cơ', 'có_dễ', 'có_họ', 'có_khi', 'có_ngày', 'có_người', 'có_nhiều', 'có_nhà', 'có_phải', 'có_số', 'có_tháng', 'có_thế', 'có_thể', 'có_vẻ', 'có_ý', 'có_ăn', 'có_điều', 'có_điều_kiện', 'có_đáng', 'có_đâu', 'có_được', ' ...

# %%
merge_phrases = ['kem chống nắng', 'kiềm dầu', 'da dầu', 'da khô',
                 'chỉ số chống nắng', 'giá cả', 'chính hãng',
                 'lừa đảo', 'kháng nước', 'chống nước', 'vệt trắng',
                 'nâng tông', 'nâng tone', 'bí da', 'dung tích']

# %% [markdown]
# ## **4.2. Hàm tiền xử lý văn bản**

# %%
def replace_merge_phrases(text, merge_phrases):
    for phrase in merge_phrases:
        underscored = phrase.replace(' ', '_')
        text = re.sub(rf"\b{re.escape(phrase)}\b", underscored, text, flags=re.IGNORECASE)
    return text

# ===== Phase 1: Normalize =====
def normalize_text(text):
    # Lowercase Sentences
    text = text.lower()
    # Loại bỏ tất cả ký tự đặc biệt, trừ chữ cái, số, dấu cách, dấu ? và !
    text = re.sub(r"[^a-zA-Z0-9À-Ỵà-ỵ\s!?]", " ", text)
    # Delete Redundant Spaces
    text = re.sub(r"\s+", " ", text).strip()
    # Delete Links
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    # Delete @mentions
    text = re.sub(r'@\w+', '', text)
    # Normalize Unicode
    text = unicodedata.normalize("NFC", text)
    # De-emoji
    text = emoji.demojize(text, delimiters=(" ", " "))

    return text

def process_text(text, remove_stopwords=True, return_str=False):
    # --- Phase 1 ---
    norm = normalize_text(text)

    # Thay thế cụm từ ghép
    norm = replace_merge_phrases(norm, merge_phrases)

    # --- Phase 2 ---
    # Tokenize
    tokens = ViTokenizer.tokenize(norm).split()
    # De-teencode
    tokens = [teencode_dict.get(tok, tok) for tok in tokens]
    # Remove stopwords
    if remove_stopwords == True:
        tokens = [tok for tok in tokens if tok not in stopword_list]
    if return_str:
        return " ".join(tokens)
    return tokens

# %% [markdown]
# Đăng ký UDF cho 3 chế độ:
# - trả về list token
# - trả về chuỗi token được nối lại
# - trả về chuỗi token được nối lại, giữ stopwords

# %%
tokenized_text_udf = udf(process_text, ArrayType(StringType()))
cleaned_text_udf = udf(lambda text: process_text(text, return_str=True), StringType())
cleaned_text_stopwords_udf = udf(lambda text: process_text(text, remove_stopwords=False, return_str=True), StringType())

# %% [markdown]
# # **5. EDA dữ liệu bình luận**

# %% [markdown]
# ## **5.1. Lọc ra comment ở các video tiếng Việt**

# %%
# Tìm các cột trùng tên giữa hai DataFrame
common_columns = list(set(video_df.columns) & set(comment_df.columns))

print("Các cột trùng tên giữa video_df và comment_df:")
for col in common_columns:
    print(col)
# Out:
# Các cột trùng tên giữa video_df và comment_df:
# text
# diggCount
# createTime
# createTimeISO

# %%
# Đổi tên các cột trùng nhau
for col in common_columns:
    video_df = video_df.withColumnRenamed(col, col + "_video")
    comment_df = comment_df.withColumnRenamed(col, col + "_comment")

# %%
# Join hai DataFrame theo cột videoWebUrl
joined_df = video_df.join(
    comment_df,
    video_df.webVideoUrl == comment_df.videoWebUrl,
    "inner"
)

joined_df.show()
# Out:
# +--------------------+------------+------------+----------------+-------------------+----------------+---------------+--------------+--------------------+-------------------+-----+-------+--------+-----------+------------+--------------------+--------+--------------------+---------+------------+----------+--------------------+------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+-------------------+------------------+---------------------+--------------------+-----+-----------------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# |          authorMeta|collectCount|commentCount|createTime_video|createTimeISO_video|detailedMentions|diggCount_video|effectStickers|            hashtags|                 id| isAd|isMuted|isPinned|isSlideshow|locationMeta|           mediaUrls|mentions|           musicMeta|playCount| searchQuery|shareCount|          text_video|textLanguage|           videoMeta|         webVideoUrl|          video_meta|duration|       hashtags_json|         videoWebUrl|   submittedVideoUrl|               input|                cid|createTime_comment|createTimeISO_comment|        text_comment|label|diggCount_comment|likedByAuthor|pinnedByAuthor|repliesToId|replyCommentTotal|                uid|        uniqueId|     avatarThumbnail|
# +--------------------+------------+------------+----------------+-------------------+----------------+---------------+--------------+--------------------+-------------------+-----+-------+--------+-----------+------------+--------------------+--------+--------------------+---------+------------+----------+--------------------+------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+-------------------+------------------+---------------------+--------------------+-----+-----------------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6978487559790527233|        1624805757|  2021-06-27 14:55:57|Cảm ơn bác sĩ chị...|  pos|                1|         true|         false|       NULL|              2.0|6761019601562387457|    minhhien3823|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6
# +--------------------+------------+------------+----------------+-------------------+----------------+---------------+--------------+--------------------+-------------------+-----+-------+--------+-----------+------------+--------------------+--------+--------------------+---------+------------+----------+--------------------+------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+-------------------+------------------+---------------------+--------------------+-----+-----------------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# only showing top 20 rows

# %%
# Lọc ra các comment trong video bằng tiếng Việt (textLanguage = "vi")
vietnamese_joined_df = joined_df.filter(joined_df.textLanguage == "vi")
vietnamese_joined_df.show()
# Out:
# +--------------------+------------+------------+----------------+-------------------+----------------+---------------+--------------+--------------------+-------------------+-----+-------+--------+-----------+------------+--------------------+--------+--------------------+---------+------------+----------+--------------------+------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+-------------------+------------------+---------------------+--------------------+-----+-----------------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# |          authorMeta|collectCount|commentCount|createTime_video|createTimeISO_video|detailedMentions|diggCount_video|effectStickers|            hashtags|                 id| isAd|isMuted|isPinned|isSlideshow|locationMeta|           mediaUrls|mentions|           musicMeta|playCount| searchQuery|shareCount|          text_video|textLanguage|           videoMeta|         webVideoUrl|          video_meta|duration|       hashtags_json|         videoWebUrl|   submittedVideoUrl|               input|                cid|createTime_comment|createTimeISO_comment|        text_comment|label|diggCount_comment|likedByAuthor|pinnedByAuthor|repliesToId|replyCommentTotal|                uid|        uniqueId|     avatarThumbnail|
# +--------------------+------------+------------+----------------+-------------------+----------------+---------------+--------------+--------------------+-------------------+-----+-------+--------+-----------+------------+--------------------+--------+--------------------+---------+------------+----------+--------------------+------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+-------------------+------------------+---------------------+--------------------+-----+-----------------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6978487559790527233|        1624805757|  2021-06-27 14:55:57|Cảm ơn bác sĩ chị...|  pos|                1|         true|         false|       NULL|              2.0|6761019601562387457|    minhhien3823|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6977749499381121793|        1624633914|  2021-06-25 15:11:54|Có loại kcn vật l...|  neu|                3|         true|         false|       NULL|              1.0|6632594423325081602|   tuyetphan1304|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6980963679337005851|        1625382280|  2021-07-04 07:04:40|dùng laros toàn đ...|  neg|                2|        false|         false|       NULL|              1.0|6829700150342452225|     binh.t.pham|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6977385265648173826|        1624549108|  2021-06-24 15:38:28|Da dầu thì sài sữ...|  neu|                2|         true|         false|       NULL|              1.0|6688178827048649729|        ngpu0110|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6977383620424762138|        1624548769|  2021-06-24 15:32:49|còn kem chống nắn...|  neu|                4|         true|         false|       NULL|              0.0|6575418490651672577|      trngan2209|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6980928297367257882|        1625374043|  2021-07-04 04:47:23|chị ơi e da dầu m...|  neu|                2|        false|         false|       NULL|              0.0|6612087094297034753|        huupuc11|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6977600660372554497|        1624599262|  2021-06-25 05:34:22|cô ơi test sữa rử...|  neu|                2|        false|         false|       NULL|              0.0|6854111250826658817|      hyphuong12|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6990764291179905818|        1627664162|  2021-07-30 16:56:02|E lan dau xài kcn...|  neg|                1|        false|         false|       NULL|              0.0|        68042623127|     im.huong29_|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6981463448757191450|        1625498641|  2021-07-05 15:24:01|chị ơi e da dầu d...|  neg|                1|        false|         false|       NULL|              0.0|6861503524477191170|22062020quynhchi|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6980661572121854747|        1625311941|  2021-07-03 11:32:21|da đâu mụn dùng e...|  neu|                1|        false|         false|       NULL|              0.0|6733177592789189633|    huendeyyy_01|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6979129336007852802|        1624955182|  2021-06-29 08:26:22|Cô review srm trà...|  neu|                1|        false|         false|       NULL|              0.0|6702716729087181825|      gumiho0102|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6977945322748478209|        1624679510|  2021-06-26 03:51:50|da thường thì xài...|  neu|                1|        false|         false|       NULL|              0.0|6933453439852119042|    chuthu111607|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7042487303478330114|        1639706869|  2021-12-17 02:07:49|         mua ở đâu c|  neu|                0|        false|         false|       NULL|              0.0|7022815865822004226|     leduyen38b1|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7040232429055410945|        1639181871|  2021-12-11 00:17:51|bác sĩ làm clip r...|  neu|                0|        false|         false|       NULL|              0.0|7006476149749269505|    thu_nhi_2206|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7015880551966327578|        1633511994|  2021-10-06 09:19:54|Vichy e muốn khóc...|  neg|                0|        false|         false|       NULL|              0.0|6640201136861544450|     doanlinh435|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7012420241431184154|        1632706328|  2021-09-27 01:32:08|Cô ơi kcn laroche...|  neu|                0|        false|         false|       NULL|              0.0|6553016504908218370|        naviels1|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7010237850784662273|        1632198203|  2021-09-21 04:23:23|Da khô xài loại c...|  neu|                0|        false|         false|       NULL|              0.0|7004588168265073665|     chennchen86|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7009300196111336193|        1631979884|  2021-09-18 15:44:44|Da hhtd ít mụn mà...|  neu|                0|        false|         false|       NULL|              0.0|6552639789862387714|       thaoan.94|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|7008426021674664730|        1631776351|  2021-09-16 07:12:31|biodermar không k...|  neg|                0|        false|         false|       NULL|              0.0|6605822870475063298| huyenhuyen99991|https://p16-sign-...|
# |{'id': '680326654...|          60|          45|      1624544859|2021-06-24 14:27:39|              []|           1481|            []|[{'id': '16397456...|6977367028873055489|false|  false|   false|      false|        NULL|['https://api.api...|      []|{'musicName': 'nh...|    85500|kcn la roche|       131|Kem chống nắng dà...|          vi|{'height': 1024, ...|https://www.tikto...|{1024, 576, 34, h...|      34|[{163974567079219...|https://www.tikto...|https://www.tikto...|https://www.tikto...|6998492825595675418|        1629463595|  2021-08-20 12:46:35|Trong mấy loại nà...|  neu|                0|        false|         false|       NULL|              0.0|6822605069981647873|   hathunguyen93|https://p16-sign-...|
# +--------------------+------------+------------+----------------+-------------------+----------------+---------------+--------------+--------------------+-------------------+-----+-------+--------+-----------+------------+--------------------+--------+--------------------+---------+------------+----------+--------------------+------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+-------------------+------------------+---------------------+--------------------+-----+-----------------+-------------+--------------+-----------+-----------------+-------------------+----------------+--------------------+
# only showing top 20 rows

# %%
# Lấy các cột về bình luận và nhãn
df = vietnamese_joined_df.select("cid", "text_comment", "label")
df.show(20, truncate=100)
# Out:
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# |                cid|                                                                                        text_comment|label|
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# |6978487559790527233|                                                     Cảm ơn bác sĩ chị đang dùnh la roch thấy ok lắm|  pos|
# |6977749499381121793|                                            Có loại kcn vật lý hoặc vật lý lai hoá học kiềm dầu ko ạ|  neu|
# |6980963679337005851|                                         dùng laros toàn để lại ghét k à. bôi xong k tán ra nổi luôn|  neg|
# |6977385265648173826|                                                            Da dầu thì sài sữa rửa mặt nào v chị ???|  neu|
# |6977383620424762138|                                                        còn kem chống nắng cho da thường thì sao ạ??|  neu|
# |6980928297367257882|                                     chị ơi e da dầu mụn ẩn sd kcn cell fusionC clear có phù hợp k ạ|  neu|
# |6977600660372554497|                                                                 cô ơi test sữa rửa mặt simple đi cô|  neu|
# |6990764291179905818|E lan dau xài kcn xài eucerin mà mồ hôi mồ kê nó đổ tùm lum cảm giác khó chịu vãi có ai bị vậy kh...|  neg|
# |6981463448757191450|                 chị ơi e da dầu dùng kcn laroche bị vệt trắng và vón cục thì dùng loại nào ok hơn ạ|  neg|
# |6980661572121854747|                                                                     da đâu mụn dùng eucerin ổn kh ạ|  neu|
# |6979129336007852802|                                                                       Cô review srm trà xanh đc k ạ|  neu|
# |6977945322748478209|                   da thường thì xài sửa rửa mặt nào vậy bác sĩ con đag học lớp8 mong bác sĩ rep ạ😳|  neu|
# |7042487303478330114|                                                                                         mua ở đâu c|  neu|
# |7040232429055410945|                                        bác sĩ làm clip review về kcn Cell Fusion C cho da dầu đi ạ.|  neu|
# |7015880551966327578|                                                                           Vichy e muốn khóc luôn 😂|  neg|
# |7012420241431184154|                             Cô ơi kcn laroche loại hộp vuông da nhạy cảm với mụn dùng được không ạ?|  neu|
# |7010237850784662273|                                                           Da khô xài loại chống nắng nào chị 🥰🥰🥰|  neu|
# |7009300196111336193|                                              Da hhtd ít mụn mà đang treat thì dùng kcn nào ý bác ơi|  neu|
# |7008426021674664730|                                                                    biodermar không kiềm dầu tốt đâu|  neg|
# |6998492825595675418|                                                    Trong mấy loại này thì loại nào nâng tông hả chị|  neu|
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# only showing top 20 rows

# %%
print(f"Có tổng cộng {df.count()} bình luận được lấy từ các video tiếng Việt")
# Out:
# Có tổng cộng 11299 bình luận được lấy từ các video tiếng Việt

# %%
# Áp dụng xử lý lên cột text_comment
df_tokenized = df.withColumn("tokens", tokenized_text_udf(col("text_comment")))
df_cleaned = df.withColumn("cleaned_text", cleaned_text_udf(col("text_comment")))
df_cleaned_stopwords = df.withColumn("cleaned_text_stopwords", cleaned_text_stopwords_udf(col("text_comment")))

print("Tokenized Dataframe:")
print(df_tokenized.select("text_comment", "tokens").show(truncate=100))
print()
print("Cleaned Dataframe:")
print(df_cleaned.select("text_comment", "cleaned_text").show(truncate=100))
print()
print("Cleaned Dataframe, keep stopwords:")
print(df_cleaned_stopwords.select("text_comment", "cleaned_text_stopwords").show(truncate=100))
# Out:
# Tokenized Dataframe:
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+
# |                                                                                        text_comment|                                                                                  tokens|
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+
# |                                                     Cảm ơn bác sĩ chị đang dùnh la roch thấy ok lắm|                                                       [bác_sĩ, dùnh, la, roch, ok, lắm]|
# |                                            Có loại kcn vật lý hoặc vật lý lai hoá học kiềm dầu ko ạ|                                           [kcn, vật_lý, vật_lý, lai, hoá_học, kiềm_dầu]|
# |                                         dùng laros toàn để lại ghét k à. bôi xong k tán ra nổi luôn|                                                [laros, toàn, ghét, bôi, xong, tán, nổi]|
# |                                                            Da dầu thì sài sữa rửa mặt nào v chị ???|                                                   [da_dầu, sài, sữa, rửa, mặt, ?, ?, ?]|
# |                                                        còn kem chống nắng cho da thường thì sao ạ??|                                                              [kem_chống_nắng, da, ?, ?]|
# |                                     chị ơi e da dầu mụn ẩn sd kcn cell fusionC clear có phù hợp k ạ|                                        [da_dầu, mụn, ẩn, sd, kcn, cell, fusionc, clear]|
# |                                                                 cô ơi test sữa rửa mặt simple đi cô|                                                       [test, sữa, rửa, mặt, simple, đi]|
# |E lan dau xài kcn xài eucerin mà mồ hôi mồ kê nó đổ tùm lum cảm giác khó chịu vãi có ai bị vậy kh...|[lan, dau, xài, kcn, xài, eucerin, mồ_hôi, mồ, kê, đổ, tùm_lum, cảm_giác, khó_chịu, vãi]|
# |                 chị ơi e da dầu dùng kcn laroche bị vệt trắng và vón cục thì dùng loại nào ok hơn ạ|                                         [da_dầu, kcn, laroche, vệt_trắng, vón, cục, ok]|
# |                                                                     da đâu mụn dùng eucerin ổn kh ạ|                                                                  [da, mụn, eucerin, ổn]|
hhtd ít mụn mà đang treat thì dùng kcn nào ý bác ơi|                                              da hhtd ít mụn mà đang treat thì dùng kcn nào ý bác ơi|
# |                                                                    biodermar không kiềm dầu tốt đâu|                                                                    biodermar không kiềm_dầu tốt đâu|
# |                                                    Trong mấy loại này thì loại nào nâng tông hả chị|                                                    trong mấy loại này thì loại nào nâng_tông hả chị|
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# None

# %% [markdown]
# ## **5.2. Dùng Count Vectorizer thống kê tần suất xuất hiện của từ**

# %%
cv = CountVectorizer(inputCol="tokens", outputCol="features", vocabSize=5000, minDF=2.0)
cv_model = cv.fit(df_tokenized)
result = cv_model.transform(df_tokenized)

vocabulary = cv_model.vocabulary  # từ gốc

# %%
# Chuyển vector thành danh sách số
def vector_to_array(v):
    return v.toArray().tolist()

vector_to_array_udf = udf(vector_to_array, ArrayType(DoubleType()))
word_freq_df = result.withColumn("freq_array", vector_to_array_udf(col("features")))

# %%
# RDD chứa vector tần suất
freq_rdd = result.select("features").rdd.map(lambda row: row["features"].toArray())

# Cộng tất cả vector (element-wise sum)
total_freq = freq_rdd.reduce(lambda x, y: x + y)

# Ghép từ vựng với tần suất
word_freq = list(zip(vocabulary, total_freq))

# Sắp xếp giảm dần theo tần suất
word_freq_sorted = sorted(word_freq, key=lambda x: -x[1])

# %% [markdown]
# ### 5.2.1. Thống kê các từ xuất hiện nhiều nhất

# %%
for word, freq in word_freq_sorted[:30]:
    print(f"{word}: {int(freq)}")
# Out:
# da: 1404
# kcn: 1401
# mua: 986
# pass: 959
# đi: 866
# mụn: 825
# tím: 703
# xanh: 659
# xài: 655
# nha: 651
# tui: 621
# da_dầu: 596
# lắm: 567
# bôi: 537
# ?: 515
# tao: 494
# màu: 485
# beplain: 428
# 1: 415
# kem: 402
# nắng: 372
# ok: 369
# mặt: 358
# sài: 357
# dầu: 353
# chống: 348
# lá: 347
# nâng_tone: 324
# anessa: 318
# đẹp: 309

# %%
# Tạo một dictionary từ danh sách (word, frequency)
word_freq_dict = dict(word_freq_sorted)

# Tạo word cloud
wordcloud = WordCloud(font_path='montserrat.ttf', width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 5.2.2. Thống kê các từ có 2 âm tiết trở lên xuất hiện nhiều nhất

# %%
for word, freq in word_freq_sorted:
    if "_" in word:
        print(f"{word}: {int(freq)}")
# Out:
# da_dầu: 596
# nâng_tone: 324
# da_khô: 294
# kem_chống_nắng: 278
# kiềm_dầu: 274
# tẩy_trang: 217
# mồ_hôi: 111
# nâng_tông: 108
# nhạy_cảm: 92
# chính_hãng: 86
# hỗn_hợp: 83
# sản_phẩm: 61
# kích_ứng: 50
# bình_thường: 48
# tự_nhiên: 42
# việt_nam: 40
# tham_khảo: 40
# vật_lý: 39
# trộm_vía: 38
# chống_nước: 37
# cảm_giác: 33
# khó_chịu: 32
# khẩu_trang: 32
# kháng_nước: 31
# bí_da: 29
# tuyệt_vời: 29
# người_ta: 28
# bác_sĩ: 27
# kinh_khủng: 26
# đại_hội: 26
# máy_lạnh: 6
# anh_trai: 6
# bon_chen: 6
# đen_thui: 6
# ê_hề: 5
# người_yêu: 5
# quan_điểm: 5
# nạn_nhân: 5
# màu_da: 5
# chi_tiết: 5
# hàng_xách: 5
# tăng_giá: 5
# tế_bào: 5
# công_việc: 5
# nha_k: 5
# ưng_ý: 5
# đồng_ý: 5
# ban_đầu: 5
# thời_tiết: 5
# mĩ_phẩm: 5
# gia_công: 5
# sinh_viên: 5
# thường_xuyên: 5
# khí_hậu: 4
# lên_lớp: 4
# hạn_chế: 4
# hong_dạ: 4
# nắng_nóng: 4
# trang_điểm: 4
# tối_sầm: 4
# sài_k: 4
# trắng_tinh: 4
# yên_tử: 4
# thiết_kế: 4
# ko_hợp: 4
# kết_quả: 4
# gợi_ý: 4
# vô_tư: 4
# bí_quyết: 4
# thành_công: 4
# nội_tiết: 4
# chú_ý: 4
# lựa_chọn: 4
# trưng_bày: 4
# tha_thiết: 4
# đơn_giản: 4
# quang_phổ: 4
# cải_tiến: 4
# đam_mê: 4
# cố_chấp: 4
# ám_ảnh: 4
# cẩn_thận: 4
# na_ná: 4
# kết_bạn: 4
# nha_mn: 4
# du_lịch: 4
# vậy_e: 4
# có_giá: 4
# thế_giới: 4
# giấy_thấm: 4
# nước_mắt: 4
# kết_cấu: 4
# hạt_dẻ: 4
# nhạy_cảm_sài: 4
# quyết_định: 4
# thu_hồi: 4
# quá_chừng: 4
# năm_ngoái: 4
# nhạy_cảm_ko: 4
# thể_nào: 3
# chu_trình: 3
# tham_gia: 3
# đéo_bao_giờ: 3
# thanh_xuân: 3
# góp_ý: 3
# da_sần_sùi: 3
# đầy_đủ: 3
# giá_cả: 3
# bảo_quản: 3
# tâm_huyết: 3
# hàng_đầu: 3
# hợp_lí: 3
# chỉ_số_chống_nắng: 3
# ghê_á: 3
# trắng_bóc: 3
# tin_dùng: 3
# bóng_loáng: 3
# rõ_ràng: 3
# tủ_lạnh: 3
# thay_thế: 3
# hợp_lý: 3
# nha_t: 3
# sản_phẩm_chất_lượng: 3
# để_dành: 3
# chi_nhánh: 3
# quần_áo: 3
# tính_chất: 3
# hoá_đơn: 3
# thương_hiệu: 3
# danh_sách: 3
# hương_liệu: 3
# sự_kiện: 3
# theo_dõi: 3
# lên_tiếng: 3
# độ_ẩm: 3
# diễn_viên: 3
# di_ạ: 3
# thẳng_thắn: 3
# rõ_rệt: 3
# cần_thiết: 3
# nha_má: 3
# nhạy_cảm_ok: 3
# nhạy_cảm_e: 3
# xuất_sắc: 3
# chân_thật: 3
# sợ_hãi: 3
# hầu_như: 3
# giải_phóng: 3
# hay_hóa: 3
# hoàng_sa: 3
# giải_quyết: 3
# thiên_nhiên: 3
# thẩm_thấu: 3
# tinh_thần: 3
# hú_hồn: 3
# kinh_khủng_khiếp: 3
# phụ_thuộc: 3
# phát_hiện: 3
# khổ_thân: 3
# công_đức: 3
# nhân_viên: 3
# chăm_sóc: 3
# êm_ru: 3
# tiếp_xúc: 3
# địa_chỉ: 3
# á_e: 3
# đánh_phấn: 2
# hầu_như_ai: 2
# di_băng: 2
# ngon_lành: 2
# lưu_ý: 2
# công_dụng: 2
# phụ_nữ: 2
# xinh_vậy: 2
# lên_tay: 2
# quân_đội: 2
# gò_má: 2
# trứng_cá: 2
# bí_bách: 2
# dữ_dội: 2
# hoá_ra: 2
# y_vậy: 2
# đa_số: 2
# nguyên_nhân: 2
# mạnh_thế: 2
# im_lặng: 2
# bến_xe_nước_ngầm: 2
# hạnh_phúc: 2
# hi_sinh: 2
# vệ_sinh: 2
# kiểm_tra: 2
# tự_tin: 2
# liên_hệ: 2
# bỏ_qua: 2
# phông_chữ: 2
# sài_sao: 2
# dung_dịch: 2
# lí_do: 2
# lấp_lánh: 2
# ẩn_nha: 2
# bản_chất: 2
# môi_trường: 2
# đỏ_thế: 2
# tất_nhiên: 2
# giấy_tờ: 2
# dưa_hấu: 2
# kinh_tế: 2
# cơ_bản: 2
# trước_mắt: 2
# đánh_đồng: 2
# ma_sát: 2
# che_phủ: 2
# suy_nghĩ: 2
# mướt_mượt: 2
# có_lẽ: 2
# ngăm_ngăm: 2
# sần_sùi: 2
# ai_ngờ: 2
# nha_tt: 2
# phân_phối: 2
# chẳng_hiểu_sao: 2
# tại_chỗ: 2
# ung_thư: 2
# giá_như: 2
# tùy_da: 2
# đầu_video: 2
# thâm_quầng: 2
# tin_tưởng: 2
# loại_bỏ: 2
# năn_nỉ: 2
# xem_xét: 2
# ko_vậy: 2
# trung_thành: 2
# nhẹ_tênh: 2
# hồng_vậy: 2
# nhiệm_vụ: 2
# dậy_thì: 2
# máy_tính: 2
# mẹ_mày: 2
# chủ_yếu: 2
# tiểu_thư: 2
# không_sao: 2
# nhạy_cảm_em: 2
# tương_tự: 2
# xứng_đáng: 2
# đầu_tư: 2
# da_em: 2
# thảm_hoạ: 2

# %%
word_freq_dict_2_syllable = {word: freq for word, freq in word_freq_sorted if "_" in word}

wordcloud_2_syllable = WordCloud(font_path='montserrat.ttf', width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict_2_syllable)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_2_syllable, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## **5.3. POS Tagging**

# %%
texts = [row["cleaned_text_stopwords"] for row in df_cleaned_stopwords.select("cleaned_text_stopwords").collect()]

# Khởi tạo bộ đếm
noun_counter = Counter()
verb_counter = Counter()
adj_counter = Counter()

for text in texts:
    words, tags = ViPosTagger.postagging(text)

    for word, tag in zip(words, tags):
        if tag == 'N':
            noun_counter[word] += 1
        elif tag == 'V':
            verb_counter[word] += 1
        elif tag == 'A':
            adj_counter[word] += 1

# %%
def plot_wordcloud(counter, title):
    wordcloud = WordCloud(font_path='montserrat.ttf', background_color='white', width=800, height=400).generate_from_frequencies(counter)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title)
    plt.show()

# %%
# Vẽ kết quả
plot_wordcloud(noun_counter, "WordCloud - Danh từ")
plot_wordcloud(verb_counter, "WordCloud - Động từ")
plot_wordcloud(adj_counter, "WordCloud - Tính từ")

# %%
# Vẽ các danh từ có 2 âm tiết trở lên
counter_2_syllable = {word: freq for word, freq in noun_counter.items() if "_" in word}
plot_wordcloud(counter_2_syllable, "Wordcloud - Danh từ (2 âm tiết trở lên)")

# %% [markdown]
# ## **5.4. Phân phối bình luận theo từng nhãn**

# %% [markdown]
# Lọc df_labeled lấy những comment được gắn nhãn

# %%
df_labeled = df.filter(df.label.isNotNull())
print(df_labeled.show(truncate=100))
print("Number of labeled comments:", df_labeled.count())
# Out:
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# |                cid|                                                                                        text_comment|label|
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# |6978487559790527233|                                                     Cảm ơn bác sĩ chị đang dùnh la roch thấy ok lắm|  pos|
# |6977749499381121793|                                            Có loại kcn vật lý hoặc vật lý lai hoá học kiềm dầu ko ạ|  neu|
# |6980963679337005851|                                         dùng laros toàn để lại ghét k à. bôi xong k tán ra nổi luôn|  neg|
# |6977385265648173826|                                                            Da dầu thì sài sữa rửa mặt nào v chị ???|  neu|
# |6977383620424762138|                                                        còn kem chống nắng cho da thường thì sao ạ??|  neu|
# |6980928297367257882|                                     chị ơi e da dầu mụn ẩn sd kcn cell fusionC clear có phù hợp k ạ|  neu|
# |6977600660372554497|                                                                 cô ơi test sữa rửa mặt simple đi cô|  neu|
# |6990764291179905818|E lan dau xài kcn xài eucerin mà mồ hôi mồ kê nó đổ tùm lum cảm giác khó chịu vãi có ai bị vậy kh...|  neg|
# |6981463448757191450|                 chị ơi e da dầu dùng kcn laroche bị vệt trắng và vón cục thì dùng loại nào ok hơn ạ|  neg|
# |6980661572121854747|                                                                     da đâu mụn dùng eucerin ổn kh ạ|  neu|
# |6979129336007852802|                                                                       Cô review srm trà xanh đc k ạ|  neu|
# |6977945322748478209|                   da thường thì xài sửa rửa mặt nào vậy bác sĩ con đag học lớp8 mong bác sĩ rep ạ😳|  neu|
# |7042487303478330114|                                                                                         mua ở đâu c|  neu|
# |7040232429055410945|                                        bác sĩ làm clip review về kcn Cell Fusion C cho da dầu đi ạ.|  neu|
# |7015880551966327578|                                                                           Vichy e muốn khóc luôn 😂|  neg|
# |7012420241431184154|                             Cô ơi kcn laroche loại hộp vuông da nhạy cảm với mụn dùng được không ạ?|  neu|
# |7010237850784662273|                                                           Da khô xài loại chống nắng nào chị 🥰🥰🥰|  neu|
# |7009300196111336193|                                              Da hhtd ít mụn mà đang treat thì dùng kcn nào ý bác ơi|  neu|
# |7008426021674664730|                                                                    biodermar không kiềm dầu tốt đâu|  neg|
# |6998492825595675418|                                                    Trong mấy loại này thì loại nào nâng tông hả chị|  neu|
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# only showing top 20 rows
#
# None
# Number of labeled comments: 3138

# %%
def plot_label_distribution(df, title="Số lượng bình luận theo nhãn", label_col="label"):
    # Count the number of comments for each label
    label_counts = df.groupBy("label").agg(F.count("*").alias("count"))

    # Convert to Pandas DataFrame for plotting
    label_counts_pd = label_counts.toPandas()

    # Plotting the bar chart
    plt.figure(figsize=(8, 6))
    bars = plt.bar(label_counts_pd["label"], label_counts_pd["count"], color='skyblue')

    # Thêm số lên trên mỗi cột
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height + 5, str(height),
                ha='center', va='bottom', fontsize=10)

    plt.xlabel("Labels")
    plt.ylabel("Số lượng bình luận")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
plot_label_distribution(df_labeled, label_col="label")

# %% [markdown]
# ## **5.5. Phân phối bình luận theo số lượng từ**

# %%
df_tokenized = df_labeled.withColumn("tokens", tokenized_text_udf(col("text_comment")))
token_counts = df_tokenized.select(F.size("tokens").alias("token_count"))
token_counts_list = [row.token_count for row in token_counts.collect()]

# %%
plt.hist(token_counts_list, bins=40)
plt.xlabel("Số lượng từ")
plt.ylabel("Số lượng bình luận")
plt.title("Phân phối số lượng từ trong bình luận")
plt.show()

# %% [markdown]
# ---
# # **6. Xây dựng mô hình phân tích quan điểm**
# ---

# %% [markdown]
# ## **6.1. Mã hóa cột label**
# - neg (Negative) => 0
# - neu (Neutral) => 1
# - pos (Positive) => 2

# %%
df_labeled = df_labeled.withColumn(
    "label_encoded",
    F.when(col("label") == "neg", 0)
    .when(col("label") == "neu", 1)
    .when(col("label") == "pos", 2)
)

df_labeled.show(truncate=50)
# Out:
# +-------------------+--------------------------------------------------+-----+-------------+
# |                cid|                                      text_comment|label|label_encoded|
# +-------------------+--------------------------------------------------+-----+-------------+
# |6978487559790527233|   Cảm ơn bác sĩ chị đang dùnh la roch thấy ok lắm|  pos|            2|
# |6977749499381121793|Có loại kcn vật lý hoặc vật lý lai hoá học kiềm...|  neu|            1|
# |6980963679337005851|dùng laros toàn để lại ghét k à. bôi xong k tán...|  neg|            0|
# |6977385265648173826|          Da dầu thì sài sữa rửa mặt nào v chị ???|  neu|            1|
# |6977383620424762138|      còn kem chống nắng cho da thường thì sao ạ??|  neu|            1|
# |6980928297367257882|chị ơi e da dầu mụn ẩn sd kcn cell fusionC clea...|  neu|            1|
# |6977600660372554497|               cô ơi test sữa rửa mặt simple đi cô|  neu|            1|
# |6990764291179905818|E lan dau xài kcn xài eucerin mà mồ hôi mồ kê n...|  neg|            0|
# |6981463448757191450|chị ơi e da dầu dùng kcn laroche bị vệt trắng v...|  neg|            0|
# |6980661572121854747|                   da đâu mụn dùng eucerin ổn kh ạ|  neu|            1|
# |6979129336007852802|                     Cô review srm trà xanh đc k ạ|  neu|            1|
# |6977945322748478209|da thường thì xài sửa rửa mặt nào vậy bác sĩ co...|  neu|            1|
# |7042487303478330114|                                       mua ở đâu c|  neu|            1|
# |7040232429055410945|bác sĩ làm clip review về kcn Cell Fusion C cho...|  neu|            1|
# |7015880551966327578|                         Vichy e muốn khóc luôn 😂|  neg|            0|
# |7012420241431184154|Cô ơi kcn laroche loại hộp vuông da nhạy cảm vớ...|  neu|            1|
# |7010237850784662273|         Da khô xài loại chống nắng nào chị 🥰🥰🥰|  neu|            1|
# |7009300196111336193|Da hhtd ít mụn mà đang treat thì dùng kcn nào ý...|  neu|            1|
# |7008426021674664730|                  biodermar không kiềm dầu tốt đâu|  neg|            0|
# |6998492825595675418|  Trong mấy loại này thì loại nào nâng tông hả chị|  neu|            1|
# +-------------------+--------------------------------------------------+-----+-------------+
# only showing top 20 rows

# %% [markdown]
# ## **6.2. Chia dữ liệu huấn luyện, đánh giá, kiểm tra**
#
# Sử dụng phương pháp stratified split để đảm bảo rằng mỗi tập con có tỉ lệ nhãn tương ứng như toàn bộ tập dữ liệu.

# %%
# Hàm chia stratified
def stratified_split(df, label_col='label', train_frac=0.65, val_frac=0.15, test_frac=0.2, seed=42):
    labels = [row[label_col] for row in df.select(label_col).distinct().collect()]

    train_dfs = []
    val_dfs = []
    test_dfs = []

    for lbl in labels:
        df_lbl = df.filter(F.col(label_col) == lbl)
        train, val_test = df_lbl.randomSplit([train_frac, 1 - train_frac], seed=seed)
        val, test = val_test.randomSplit([val_frac / (val_frac + test_frac), test_frac / (val_frac + test_frac)], seed=seed)

        train_dfs.append(train)
        val_dfs.append(val)
        test_dfs.append(test)

    train_df = reduce(DataFrame.unionAll, train_dfs)
    val_df = reduce(DataFrame.unionAll, val_dfs)
    test_df = reduce(DataFrame.unionAll, test_dfs)

    return train_df, val_df, test_df

# %%
train_df, val_df, test_df = stratified_split(df_labeled, label_col='label', train_frac=0.65, val_frac=0.15, test_frac=0.2)

print("Train count:", train_df.count())
print("Validation count:", val_df.count())
print("Test count:", test_df.count())
# Out:
# Train count: 2166
# Validation count: 425
# Test count: 547

# %% [markdown]
# Lưu lại thành các file train.tsv, val.tsv, test.tsv

# %%
train_pd = train_df.toPandas()
val_pd = val_df.toPandas()
test_pd = test_df.toPandas()

# %%
train_pd.to_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/train.tsv', sep='\t', encoding='utf-8', index=False)
val_pd.to_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/val.tsv', sep='\t', encoding='utf-8', index=False)
test_pd.to_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/test.tsv', sep='\t', encoding='utf-8', index=False)

# %%
plot_label_distribution(train_df, label_col="label", title="Number of Comments per Label (Train Set)")
plot_label_distribution(val_df, label_col="label", title="Number of Comments per Label (Validation Set)")
plot_label_distribution(test_df, label_col="label", title="Number of Comments per Label (Test Set)")

# %% [markdown]
# ## **6.3. PhoBERT + Classifiers**

# %% [markdown]
# ### 6.3.1. Trích xuất đặc trưng từ văn bản dùng PhoBERT base v2

# %%
phobert = AutoModel.from_pretrained("vinai/phobert-base-v2")
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base-v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at vinai/phobert-base-v2 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.13M [00:00<?, ?B/s]

# %%
# Tải dữ liệu train, val, test đã được chia ở phân trước
train_pd = pd.read_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/train.tsv', sep='\t')
val_pd = pd.read_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/val.tsv', sep='\t')
test_pd = pd.read_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/test.tsv', sep='\t')
train_pd.head(4)
# Out:
#                    cid                                       text_comment  \
# 0  6882343591239565313  Nhược điểm duy nhất: xuống tông sạm đen vào cu...
# 1  6883704234718855170  e này dùng thích lắm nhé😂mình đang dùng thấy n...
# 2  6955423544113725441  mình củng đang xài dạng tuýp này.nó ko bị bết ...
# 3  6978487559790527233    Cảm ơn bác sĩ chị đang dùnh la roch thấy ok lắm
#
#   label  label_encoded
# 0   pos              2
# 1   pos              2
# 2   pos              2
# 3   pos              2

# %% [markdown]
# Tiền xử lý văn bản bình luận, chọn return_str=True để trả về chuỗi token được nối lại với nhau bằng khoảng trắng

# %%
train_pd['cleaned_text'] = train_pd['text_comment'].apply(lambda x: process_text(x, return_str=True))
val_pd['cleaned_text'] = val_pd['text_comment'].apply(lambda x: process_text(x, return_str=True))
test_pd['cleaned_text'] = test_pd['text_comment'].apply(lambda x: process_text(x, return_str=True))
train_pd.head(4)
# Out:
#                    cid                                       text_comment  \
# 0  6882343591239565313  Nhược điểm duy nhất: xuống tông sạm đen vào cu...
# 1  6883704234718855170  e này dùng thích lắm nhé😂mình đang dùng thấy n...
# 2  6955423544113725441  mình củng đang xài dạng tuýp này.nó ko bị bết ...
# 3  6978487559790527233    Cảm ơn bác sĩ chị đang dùnh la roch thấy ok lắm
#
#   label  label_encoded                                       cleaned_text
# 0   pos              2  nhược_điểm duy_nhất tông sạm đen khả_năng bảo_...
# 1   pos              2  lắm thấm lắm thoa nâng_tone nx mặt mụn bt nc ư...
# 2   pos              2               củng xài dạng tuýp bết dính tông nhẹ
# 3   pos              2                         bác_sĩ dùnh la roch ok lắm

# %% [markdown]
# Hàm extract_features trả về một vector NumPy 1 chiều đại diện cho embedding của cả câu, được tính bằng cách trung bình tất cả các vector ẩn (hidden states) của các token.

# %%
def extract_features(text):
    input_ids = torch.tensor([tokenizer.encode(text, add_special_tokens=True)])
    with torch.no_grad():
        outputs = phobert(input_ids)
        last_hidden_state = outputs[0]
        sentence_embedding = last_hidden_state.mean(dim=1).squeeze().numpy()
    return sentence_embedding

# %% [markdown]
# Trích feature cho 3 tập train, val, test

# %%
tqdm.pandas()  # Để theo dõi tiến trình

print("Traning Set")
train_pd["features"] = train_pd["text_comment"].progress_apply(extract_features)
print("\nValidation Set")
val_pd["features"] = val_pd["text_comment"].progress_apply(extract_features)
print("\nTest Set")
test_pd["features"] = test_pd["text_comment"].progress_apply(extract_features)
# Out:
# Traning Set
# 100%|██████████| 2166/2166 [05:10<00:00,  6.97it/s]
# Validation Set
# 100%|██████████| 425/425 [01:05<00:00,  6.50it/s]
# Test Set
# 100%|██████████| 547/547 [01:16<00:00,  7.18it/s]

# %%
X_train = np.vstack(train_pd["features"].values)
y_train = train_pd["label_encoded"].values

X_val = np.vstack(val_pd["features"].values)
y_val = val_pd["label_encoded"].values

X_test = np.vstack(test_pd["features"].values)
y_test = test_pd["label_encoded"].values

# %% [markdown]
# ### **6.3.2 PhoBERT + ML models & Hyperparameter tuning**

# %%
# Hàm tối ưu hóa siêu tham số:  k-fold cross validation cùng với random search
def optimize_model(model_name, X, y, param_dist):
    model_class = {
        'LogisticRegression': LogisticRegression,
        'SVC': SVC,
        'RandomForestClassifier': RandomForestClassifier
    }[model_name]

    model = model_class()
    random_search = RandomizedSearchCV(
        model, param_distributions=param_dist, n_iter=25, cv=5,
        n_jobs=-1, scoring='accuracy', random_state=42
    )
    random_search.fit(X, y)

    best_params = random_search.best_params_
    best_score = random_search.best_score_

    return best_params, best_score

# %%
# List các hyperparameter cần tối ưu
param_dists = {
    'LogisticRegression': {
        'C': np.logspace(-4, 4, 20),
        'penalty': ['l1', 'l2'],
        'solver': ['liblinear', 'saga']
    },
    'SVC': {
        'C': np.logspace(-2, 10, 20),
        'kernel': ['linear', 'rbf', 'poly'],
        'gamma': ['scale', 'auto'] + list(np.logspace(-9, 3, 20)),
    },
    'RandomForestClassifier': {
        'n_estimators': range(50, 500, 50),
        'max_depth': [None] + list(range(10, 110, 10)),
        'min_samples_split': range(2, 20),
        'min_samples_leaf': range(1, 20),
    }
}

# %% [markdown]
# Tối ưu hóa tham số, lưu best_params và train lại trên toàn bộ train_val với best_params

# %%
best_models = {}

for model_name, param_dist in param_dists.items():
    print(f"Optimizing {model_name}...")
    best_params, best_score = optimize_model(model_name, X_train, y_train, param_dist)
    print(f"Best hyper-parameters for {model_name}: {best_params}")
    print(f"Best accuracy: {best_score:.4f}")

    # Train lại với best_params
    model_class = {
        'LogisticRegression': LogisticRegression,
        'SVC': SVC,
        'RandomForestClassifier': RandomForestClassifier
    }[model_name]

    model = model_class(**best_params)
    model.fit(X_train, y_train)

    # Đánh giá trên tập test
    y_pred = model.predict(X_test)
    print(f"Test performance ({model_name}):")
    print(classification_report(y_test, y_pred))

    # Lưu model bằng pickle
    with open(f"/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/model/{model_name}_best_model.pkl", "wb") as f:
        pickle.dump(model, f)

    best_models[model_name] = model
    print("-" * 60)
# Out:
# Optimizing LogisticRegression...
# Best hyper-parameters for LogisticRegression: {'solver': 'saga', 'penalty': 'l2', 'C': np.float64(0.23357214690901212)}
# Best accuracy: 0.7678
# Test performance (LogisticRegression):
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       145
#            1       0.85      0.86      0.86       247
#            2       0.84      0.82      0.83       155
#
#     accuracy                           0.84       547
#    macro avg       0.84      0.84      0.84       547
# weighted avg       0.84      0.84      0.84       547
#
# ------------------------------------------------------------
# Optimizing SVC...
# Best hyper-parameters for SVC: {'kernel': 'linear', 'gamma': np.float64(1.8329807108324374e-08), 'C': np.float64(0.04281332398719394)}
# Best accuracy: 0.7512
# Test performance (SVC):
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       145
#            1       0.84      0.86      0.85       247
#            2       0.83      0.79      0.81       155
#
#     accuracy                           0.83       547
#    macro avg       0.83      0.82      0.82       547
# weighted avg       0.83      0.83      0.83       547
#
# ------------------------------------------------------------
# Optimizing RandomForestClassifier...
# Best hyper-parameters for RandomForestClassifier: {'n_estimators': 350, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_depth': 100}
# Best accuracy: 0.7018
# Test performance (RandomForestClassifier):
#               precision    recall  f1-score   support
#
#            0       0.78      0.68      0.73       145
#            1       0.76      0.90      0.82       247
#            2       0.78      0.66      0.72       155
#
#     accuracy                           0.77       547
#    macro avg       0.78      0.74      0.76       547
# weighted avg       0.77      0.77      0.77       547
#
# ------------------------------------------------------------

# %% [markdown]
# ### 6.3.3. PhoBERT + MLP

# %%
X_train = np.array(train_pd["features"].tolist())
y_train = np.array(train_pd["label_encoded"].tolist())

X_val = np.array(val_pd["features"].tolist())
y_val = np.array(val_pd["label_encoded"].tolist())

X_test = np.array(test_pd["features"].tolist())
y_test = np.array(test_pd["label_encoded"].tolist())

num_classes = len(np.unique(y_train))
y_train_cat = to_categorical(y_train, num_classes)
y_val_cat = to_categorical(y_val, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(768,), kernel_regularizer=l2(0.001)),
    Dropout(0.4),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.4),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Áp dụng EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

history = model.fit(X_train, y_train_cat,
          validation_data=(X_val, y_val_cat),
          epochs=15,
          batch_size=32,
          callbacks=[early_stopping])
# Out:
# Epoch 1/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.5214 - loss: 1.4690 - val_accuracy: 0.7176 - val_loss: 1.0717
# Epoch 2/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7348 - loss: 1.0415 - val_accuracy: 0.7694 - val_loss: 0.9280
# Epoch 3/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7558 - loss: 0.9172 - val_accuracy: 0.7624 - val_loss: 0.8671
# Epoch 4/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7823 - loss: 0.8126 - val_accuracy: 0.7576 - val_loss: 0.8357
# Epoch 5/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8022 - loss: 0.7497 - val_accuracy: 0.7506 - val_loss: 0.7958
# Epoch 6/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8270 - loss: 0.6891 - val_accuracy: 0.7600 - val_loss: 0.8007
# Epoch 7/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8335 - loss: 0.6450 - val_accuracy: 0.7647 - val_loss: 0.7728
# Epoch 8/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8288 - loss: 0.6432 - val_accuracy: 0.7765 - val_loss: 0.7447
# Epoch 9/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8426 - loss: 0.6149 - val_accuracy: 0.7671 - val_loss: 0.7483
# Epoch 10/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8345 - loss: 0.5921 - val_accuracy: 0.7576 - val_loss: 0.7683
# Epoch 11/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8382 - loss: 0.5843 - val_accuracy: 0.7671 - val_loss: 0.7403
# Epoch 12/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8721 - loss: 0.5314 - val_accuracy: 0.7576 - val_loss: 0.7849
# Epoch 13/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8698 - loss: 0.5383 - val_accuracy: 0.7624 - val_loss: 0.7268
# Epoch 14/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8564 - loss: 0.5293 - val_accuracy: 0.7600 - val_loss: 0.7256
# Epoch 15/15
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8636 - loss: 0.5169 - val_accuracy: 0.7647 - val_loss: 0.7599

# %%
def plot_train_val_loss(history):
    tr_acc = history.history['accuracy']
    tr_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # plt.subplot(1, 2, 2)
    # plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    # plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    # plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    # plt.title('Training and Validation Accuracy')
    # plt.xlabel('Epochs')
    # plt.ylabel('Accuracy')
    # plt.legend()

    plt.tight_layout
    plt.show()

# %%
plot_train_val_loss(history)

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_classes))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       145
#            1       0.86      0.84      0.85       247
#            2       0.83      0.78      0.80       155
#
#     accuracy                           0.83       547
#    macro avg       0.82      0.82      0.82       547
# weighted avg       0.83      0.83      0.83       547

# %%
with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/model/mlp_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %% [markdown]
# ## **6.4. Pseudo Labeling**

# %%
df_unlabeled = df.filter(df.label.isNull())
print(df_unlabeled.show(truncate=100))
print("Number of unlabeled comments:", df_unlabeled.count())
# Out:
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# |                cid|                                                                                        text_comment|label|
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# |7490136475579171600|                                          da hỗn hợp thiên dầu thì dùng loại nào oke mà giá hs hv ạ?| NULL|
# |7492435675065713426|                                                                                      Skin 1004 đi ạ| NULL|
# |7498591390076076808|                                                                                   sunplay đỏ đi chị| NULL|
# |7490193734711231239|                                garnie đi ạ e cg định mua nhưng mà chưa bt nó có hợp ko rv đi chị 🥰| NULL|
# |7496741736116798226|                                                                                        Beyond đi cj| NULL|
# |7492290505176761106|                                                                 cs kcn nào hơn 100k ko mà sài êm ko| NULL|
# |7492399309377159944|                                                                                  chị là da gì á chị| NULL|
# |7490209608297038600|                                                              Kcn Bioré khuyết điểm thì sao chị oiii| NULL|
# |7492335048563884818|ê bữa t nhớ có vd nào nói cái skin aqua đó là fake hay sao á ,nhìn kĩ chứ essence ấy hnhu real nó...| NULL|
# |7490129473116013330|                                                                           Lên beplain xanh lá OK ch| NULL|
# |7490028714018341650|                                                             anessa hồng dùng đc cho da dầu mụn ko ạ| NULL|
# |7492040682003006216|                                                       skin aqua kia hnhu mấy bà mua ph fake hay s á| NULL|
# |7489844326399902481|                                                                             E mới mua anessa hồng🥹| NULL|
# |7492063813379588872|                                                          kcn của garnier bản mới xanh dương ổn kh ạ| NULL|
# |7490174828461900562|                                                                                           cnp đi cj| NULL|
# |7494612066512323336|                                                                       Mn ơi dùng Woolworths đc k hả| NULL|
# |7492673635459613447|                                                                           roundlab vạch hồng chị oi| NULL|
# |7491946791077921544|                                                                               chống nắng Dr.G sao e| NULL|
# |7492745904308306696|                                                                       Thử kcn pororo cho em bé đi ạ| NULL|
# |7490510319946924808|                                                                       kcn hatomogi ổn k v c oii=(((| NULL|
# +-------------------+----------------------------------------------------------------------------------------------------+-----+
# only showing top 20 rows
#
# None
# Number of unlabeled comments: 8161

# %%
unlabeled_pd = df_unlabeled.toPandas()

# %%
unlabeled_pd['cleaned_text'] = unlabeled_pd['text_comment'].apply(lambda x: process_text(x, return_str=True))
unlabeled_pd["features"] = unlabeled_pd["text_comment"].progress_apply(extract_features)

# %%
# unlabeled_pd.to_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/unlabeled_features.tsv', sep='\t', encoding='utf-8', index=False)

# %%
unlabeled_pd = pd.read_csv('/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/data/processed/unlabeled_features.tsv', sep='\t')
unlabeled_pd.tail()
# Out:
#                       cid                                       text_comment  \
# 8156  7203744653874955035  Hiện tại hàng về rất ít, hãng đang phải nhập t...
# 8157  7203831948547670811        e dc 4 5 tiếng là mũi lại tràn dầu r a ơi 🥺
# 8158  7203958590297883419                  Anh review kcn lar bản mới đi anh
# 8159  7217841222398870299  mình xài rất oki hợp luôn sau bao nhiêu lần th...
# 8160  7211537000117093146  Em bôi kcn laroche này r để 10p xong đánh nền ...
#
#       label                      cleaned_text  \
# 8156    NaN           hàng hãng nhập hàng đức
# 8157    NaN            4 5 tiếng mũi tràn dầu
# 8158    NaN                 review kcn lar đi
# 8159    NaN                   xài oki hợp thử
# 8160    NaN  bôi kcn laroche 10p xong đánh ok
#
#                                                features
# 8156  [ 1.18560754e-01  2.68800020e-01  6.69425353e-...
# 8157  [-3.69028398e-03 -2.29879022e-02 -9.84798521e-...
# 8158  [ 1.63510740e-01  7.61169642e-02  9.59200785e-...
# 8159  [ 4.62445430e-02  1.89708740e-01 -1.80552408e-...
# 8160  [ 5.83917275e-02  4.78416458e-02 -1.26457229e-...

# %%
unlabeled_pd['features'] = unlabeled_pd['features'].apply(lambda x: np.fromstring(x[1:-1], sep=' ')) # Convert string to NumPy array
X_unlabeled = np.vstack(unlabeled_pd["features"].values)

# %%
with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/model/mlp_model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
# Dự đoán xác suất với dữ liệu chưa gán nhãn
probs = model.predict(X_unlabeled)

# Lấy độ tin cậy và nhãn tương ứng
confidences = np.max(probs, axis=1)
pseudo_labels = np.argmax(probs, axis=1)

# Chọn mẫu có độ tin cậy cao
high_confidence_mask = confidences > 0.95
X_pseudo = X_unlabeled[high_confidence_mask]
y_pseudo = pseudo_labels[high_confidence_mask]

print(f"Số lượng mẫu pseudo-label: {len(X_pseudo)}")
# Out:
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Số lượng mẫu pseudo-label: 3476

# %%
unique_labels, counts = np.unique(y_pseudo, return_counts=True)

plt.figure(figsize=(8, 6))
sns.barplot(x=unique_labels, y=counts)
plt.xlabel("Pseudo-Labels")
plt.ylabel("Count")
plt.title("Phân phối Pseudo-Labels")
plt.show()

# %%
from collections import Counter
from sklearn.utils import resample

# Kiểm tra phân phối nhãn trong pseudo-label
pseudo_dist = Counter(y_pseudo)
min_count = min(pseudo_dist.values())  # số mẫu ít nhất trong các lớp

# Gộp X và y của pseudo để dễ xử lý
pseudo_data = list(zip(X_pseudo, y_pseudo))

# Nhóm theo nhãn
grouped = {}
for x, y in pseudo_data:
    grouped.setdefault(y, []).append(x)

# Undersample từng nhóm nhãn về số lượng = min_count
X_pseudo_balanced = []
y_pseudo_balanced = []
for label, features in grouped.items():
    sampled = resample(features, n_samples=min_count, random_state=42)
    X_pseudo_balanced.extend(sampled)
    y_pseudo_balanced.extend([label] * min_count)

# Chuyển sang dạng numpy array
X_pseudo_balanced = np.array(X_pseudo_balanced)
y_pseudo_balanced = np.array(y_pseudo_balanced)

# %%
# Kiểm tra phân phối nhãn trong pseudo-label
unique_labels, counts = np.unique(y_pseudo_balanced, return_counts=True)

plt.figure(figsize=(8, 6))
sns.barplot(x=unique_labels, y=counts)
plt.xlabel("Pseudo-Labels (Balanced)")
plt.ylabel("Count")
plt.title("Phân phối Pseudo-Labels đã được xử lý mất cân bằng")
plt.show()

# %%
# Gộp với tập train thật
X_train_new = np.vstack([X_train, X_pseudo_balanced])
y_train_new = np.concatenate([y_train, y_pseudo_balanced])

# %%
# Trọng số cho mỗi mẫu
weights_real = np.ones(len(y_train))                # Trọng số = 1 cho nhãn thật
weights_pseudo = np.full(len(y_pseudo_balanced), 0.8)        # Trọng số thấp hơn cho nhãn giả

sample_weights = np.concatenate([weights_real, weights_pseudo])

# Huấn luyện lại model với sample_weight
logistic_model.fit(X_train_new, y_train_new, sample_weight=sample_weights)
# Out:
# LogisticRegression(C=0.23357214690901212, max_iter=1000, solver='saga')

# %%
svm_model.fit(X_train_new, y_train_new, sample_weight=sample_weights)
rf_model.fit(X_train_new, y_train_new, sample_weight=sample_weights)
# Out:
# RandomForestClassifier(max_depth=100, min_samples_leaf=5, min_samples_split=15,
#                        n_estimators=350)

# %%
print(classification_report(y_test, logistic_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       145
#            1       0.86      0.86      0.86       247
#            2       0.84      0.82      0.83       155
#
#     accuracy                           0.84       547
#    macro avg       0.84      0.84      0.84       547
# weighted avg       0.84      0.84      0.84       547

# %%
print(classification_report(y_test, svm_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81       145
#            1       0.84      0.85      0.85       247
#            2       0.83      0.78      0.80       155
#
#     accuracy                           0.82       547
#    macro avg       0.82      0.82      0.82       547
# weighted avg       0.82      0.82      0.82       547

# %%
print(classification_report(y_test, rf_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       145
#            1       0.79      0.86      0.82       247
#            2       0.78      0.69      0.73       155
#
#     accuracy                           0.78       547
#    macro avg       0.77      0.76      0.76       547
# weighted avg       0.77      0.78      0.77       547

# %%
# One-hot encode label
y_train_cat_new = to_categorical(y_train_new, num_classes=num_classes)


model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train_new.shape[1],), kernel_regularizer=l2(0.001)),
    Dropout(0.4),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.4),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

# Dữ liệu validation tách từ tập pseudo ban đầu hoặc từ validation thực
history2 = model.fit(X_train_new, y_train_cat_new,
          validation_data=(X_val, y_val_cat),
          epochs=15,
          batch_size=32,
          callbacks=[early_stopping])
# Out:
# Epoch 1/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6132 - loss: 1.3406 - val_accuracy: 0.7529 - val_loss: 0.9876
# Epoch 2/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8085 - loss: 0.8348 - val_accuracy: 0.7529 - val_loss: 0.8923
# Epoch 3/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8327 - loss: 0.7349 - val_accuracy: 0.7671 - val_loss: 0.8219
# Epoch 4/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8533 - loss: 0.6536 - val_accuracy: 0.7741 - val_loss: 0.7866
# Epoch 5/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8506 - loss: 0.6078 - val_accuracy: 0.7741 - val_loss: 0.7846
# Epoch 6/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8589 - loss: 0.5552 - val_accuracy: 0.7647 - val_loss: 0.7399
# Epoch 7/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8739 - loss: 0.5332 - val_accuracy: 0.7788 - val_loss: 0.7777
# Epoch 8/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8670 - loss: 0.5145 - val_accuracy: 0.7718 - val_loss: 0.7465
# Epoch 9/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8832 - loss: 0.4755 - val_accuracy: 0.7859 - val_loss: 0.7260
# Epoch 10/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8886 - loss: 0.4708 - val_accuracy: 0.7741 - val_loss: 0.7312
# Epoch 11/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8816 - loss: 0.4624 - val_accuracy: 0.7835 - val_loss: 0.7127
# Epoch 12/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8880 - loss: 0.4385 - val_accuracy: 0.7671 - val_loss: 0.7563
# Epoch 13/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8903 - loss: 0.4214 - val_accuracy: 0.7576 - val_loss: 0.7171
# Epoch 14/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9060 - loss: 0.4154 - val_accuracy: 0.7647 - val_loss: 0.7230
# Epoch 15/15
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9020 - loss: 0.4020 - val_accuracy: 0.7624 - val_loss: 0.6909

# %%
plot_train_val_loss(history2)

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_classes))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       145
#            1       0.83      0.85      0.84       247
#            2       0.80      0.81      0.81       155
#
#     accuracy                           0.82       547
#    macro avg       0.81      0.81      0.81       547
# weighted avg       0.82      0.82      0.82       547

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["neg", "neu", "pos"],
                yticklabels=["neg", "neu", "pos"])
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

y_pred_logistic = logistic_model.predict(X_test)
y_pred_svm = svm_model.predict(X_test)
y_pred_rf = rf_model.predict(X_test)

plot_confusion_matrix(y_test, y_pred_logistic, "Logistic Regression - Student")
plot_confusion_matrix(y_test, y_pred_svm, "SVM - Student")
plot_confusion_matrix(y_test, y_pred_rf, "Random Forest - Student")

# %%
with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/model/LogisticRegression_best_model.pkl", "rb") as f:
    parent_logistic_model = pickle.load(f)

with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/model/SVC_best_model.pkl", "rb") as f:
    parent_svm_model = pickle.load(f)

with open("/content/drive/MyDrive/Năm 3/Big Data/Big Data - Đồ án/model/RandomForestClassifier_best_model.pkl", "rb") as f:
    parent_rf_model = pickle.load(f)

# %%
y_pred_logistic = parent_logistic_model.predict(X_test)
y_pred_svm = parent_svm_model.predict(X_test)
y_pred_rf = parent_rf_model.predict(X_test)

plot_confusion_matrix(y_test, y_pred_logistic, "Logistic Regression - Parent")
plot_confusion_matrix(y_test, y_pred_svm, "SVM - Parent")
plot_confusion_matrix(y_test, y_pred_rf, "Random Forest - Parent")
